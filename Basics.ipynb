# %% [markdown]
# # Exploring eBay Car Sales Data
#
#
# ###  In this project, We'll work a data set of used cars from eBay kleinanzeigan,  a classified section of the German eBay website.
#
# #####    It's just sampled 50,000 data points from the full dataset, And here is the columns info:
# dateCrawled - When this ad was first crawled. All field-values are taken from this date.
# name - Name of the car.
# seller - Whether the seller is private or a dealer.
# offerType - The type of listing
# price - The price on the ad to sell the car.
# abtest - Whether the listing is included in an A/B test.
# vehicleType - The vehicle Type.
# yearOfRegistration - The year in which which year the car was first registered.
# gearbox - The transmission type.
# powerPS - The power of the car in PS.
# model - The car model name.
# kilometer - How many kilometers the car has driven.
# monthOfRegistration - The month in which which year the car was first registered.
# fuelType - What type of fuel the car uses.
# brand - The brand of the car.
# notRepairedDamage - If the car has a damage which is not yet repaired.
# dateCreated - The date on which the eBay listing was created.
# nrOfPictures - The number of pictures in the ad.
# postalCode - The postal code for the location of the vehicle.
# lastSeenOnline - When the crawler saw this ad last online.
# ##### First of all, We import the Numpy & Pandas libraries. Then, You maybe noticed that we used encoding Argument with 'pd.read_csv'; because it is decoded by "Latin-1".
# ##### After that, We used DataFrame.info() and DataFrame.head() to undrastand more about our dataframe.

# %%
import pandas as pd
import numpy as np
auto=pd.read_csv('autos.csv',encoding='Latin-1')
auto
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
auto.info()
auto.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# ##### in coming cammands, Beacause of not adhering The Column Labels of snakecase, We should change them manually by copying the dataframe columns label in a new series, and copy it's content and finally change it with the intended needs to be in Snakecase instead of CamelCase.

# %%
column_name=auto.columns.copy()
column_name
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
auto.columns=['date_Crawled', 'name', 'seller', 'offer_Type', 'price', 'ab_test',
       'vehicle_Type', 'registration_year', 'gear_box', 'power_PS', 'model',
       'odometer', 'registration_month', 'fuel_Type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_Of_Pictures', 'postal_Code',
       'last_Seen']
auto.head()
# Out:
#           date_Crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_Type   price  ab_test vehicle_Type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#     gear_box  power_PS   model   odometer  registration_month fuel_Type  \
# ...

# %%
auto.describe(include='all')
# Out:
#                date_Crawled         name  seller offer_Type  price ab_test  \
# count                 50000        50000   50000      50000  50000   50000
# unique                48213        38754       2          2   2357       2
# top     2016-03-11 22:38:16  Ford_Fiesta  privat    Angebot     $0    test
# freq                      3           78   49999      49999   1421   25756
# mean                    NaN          NaN     NaN        NaN    NaN     NaN
# std                     NaN          NaN     NaN        NaN    NaN     NaN
# min                     NaN          NaN     NaN        NaN    NaN     NaN
# 25%                     NaN          NaN     NaN        NaN    NaN     NaN
# 50%                     NaN          NaN     NaN        NaN    NaN     NaN
# 75%                     NaN          NaN     NaN        NaN    NaN     NaN
# max                     NaN          NaN     NaN        NaN    NaN     NaN
#
# ...

# %%
auto['odometer'].value_counts(dropna=False)
# Out:
# 150,000km    32424
# 125,000km     5170
# 100,000km     2169
# 90,000km      1757
# 80,000km      1436
# 70,000km      1230
# 60,000km      1164
# 50,000km      1027
# 5,000km        967
# 40,000km       819
# 30,000km       789
# 20,000km       784
# 10,000km       264
# Name: odometer, dtype: int64

# %% [markdown]
# ### Clean the Data
# now It's time to valuate the columns and their entries by checking them one by one and see the correlations if is helpful.We catagorize them to 4 subcategories. first, which does not need any change, second which that have mostly one value that are candidates to be dropped, third which need more investigation and finally the last one which numeric data stored as text that needs to be cleaned.
# We just talk about the last three ones.
# the columns date_Crawled, ad_created,last_Seen are the date type which could be transform to numeric type, so they're in fourth sub.
# And column odometer,price, could be easily transform to numeric column, so in fourth one.
# The column nr_Of_Pictures does not have any valuable content; and the columns seller and offer_type have the same information and one is additional, So in the second one.
# The Columns gear gear_box, power_PS, unrepaired_damage, fuel_Type, registration_month , model, because of some reasons need more investigation. So in the third one.

# %%
auto['price']=auto['price'].str.replace('$','')
auto['price']=auto['price'].str.replace(',','').astype(float)
auto['odometer']=auto['odometer'].str.replace('km','')
auto['odometer']=auto['odometer'].str.replace(',','').astype(float)
auto.rename({'odometer':'odometer_km'},axis=1,inplace=True)

# %%
auto.describe(include='all')
# Out:
#                date_Crawled         name  seller offer_Type         price  \
# count                 50000        50000   50000      50000  5.000000e+04
# unique                48213        38754       2          2           NaN
# top     2016-03-11 22:38:16  Ford_Fiesta  privat    Angebot           NaN
# freq                      3           78   49999      49999           NaN
# mean                    NaN          NaN     NaN        NaN  9.840044e+03
# std                     NaN          NaN     NaN        NaN  4.811044e+05
# min                     NaN          NaN     NaN        NaN  0.000000e+00
# 25%                     NaN          NaN     NaN        NaN  1.100000e+03
# 50%                     NaN          NaN     NaN        NaN  2.950000e+03
# 75%                     NaN          NaN     NaN        NaN  7.200000e+03
# max                     NaN          NaN     NaN        NaN  1.000000e+08
#
#        ab_test vehicle_Type  registration_year gear_box      power_PS  model  \
# ...

# %%
auto['odometer_km'].value_counts(dropna=False)
# Out:
# 150000.0    32424
# 125000.0     5170
# 100000.0     2169
# 90000.0      1757
# 80000.0      1436
# 70000.0      1230
# 60000.0      1164
# 50000.0      1027
# 5000.0        967
# 40000.0       819
# 30000.0       789
# 20000.0       784
# 10000.0       264
# Name: odometer_km, dtype: int64

# %%
auto['odometer_km'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
auto['odometer_km'].unique().shape
# Out:
# (13,)

# %%
auto['price'].value_counts(dropna=False).head(15)
# Out:
# 0.0       1421
# 500.0      781
# 1500.0     734
# 2500.0     643
# 1200.0     639
# 1000.0     639
# 600.0      531
# 800.0      498
# 3500.0     498
# 2000.0     460
# 999.0      434
# 750.0      433
# 900.0      420
# 650.0      419
# 850.0      410
# Name: price, dtype: int64

# %%
auto['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
auto=auto[auto['odometer_km'].between(87500,150000)]
auto.describe(include='all')
# Out:
#                date_Crawled      name  seller offer_Type         price  \
# count                 41520     41520   41520      41520  4.152000e+04
# unique                40294     32335       2          2           NaN
# top     2016-04-02 15:49:30  BMW_316i  privat    Angebot           NaN
# freq                      3        73   41519      41519           NaN
# mean                    NaN       NaN     NaN        NaN  8.237172e+03
# std                     NaN       NaN     NaN        NaN  5.072893e+05
# min                     NaN       NaN     NaN        NaN  0.000000e+00
# 25%                     NaN       NaN     NaN        NaN  9.990000e+02
# 50%                     NaN       NaN     NaN        NaN  2.450000e+03
# 75%                     NaN       NaN     NaN        NaN  5.500000e+03
# max                     NaN       NaN     NaN        NaN  1.000000e+08
#
#        ab_test vehicle_Type  registration_year gear_box      power_PS  model  \
# ...

# %%
auto=auto[auto['price'].between(0,16350)]
auto
# Out:
#               date_Crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# 11     2016-03-16 18:45:34                         Mercedes_A140_Motorschaden
# 13     2016-03-23 10:48:32                                 Audi_A3_1.6_tuning
# ...

# %%
auto.describe(include='all')
# Out:
#                date_Crawled      name  seller offer_Type         price  \
# count                 39964     39964   39964      39964  39964.000000
# unique                38823     31112       2          2           NaN
# top     2016-03-23 18:39:34  BMW_316i  privat    Angebot           NaN
# freq                      3        73   39963      39963           NaN
# mean                    NaN       NaN     NaN        NaN   3558.803899
# std                     NaN       NaN     NaN        NaN   3536.038723
# min                     NaN       NaN     NaN        NaN      0.000000
# 25%                     NaN       NaN     NaN        NaN    990.000000
# 50%                     NaN       NaN     NaN        NaN   2299.000000
# 75%                     NaN       NaN     NaN        NaN   4999.000000
# max                     NaN       NaN     NaN        NaN  16350.000000
#
#        ab_test vehicle_Type  registration_year gear_box      power_PS  model  \
# ...

# %% [markdown]
# ## Exploring the Odometer & Price column
# after finding the columns which need more investigation, first of all, we take a look on two columns 'Odometer' and price.
# after a while, we notice that both the columns have some outliers.
# to define how to size the outliers, we use the below formula:
#     a) if it is greater than Q3+1.5(IQR)
#     b) if it is lower than Q1-1.5(IQR)
# we should these values which are in this criteria.
# for 'price' column, the unforbidden criteria is (0,16350)
# for 'odometer_km' column, the criteria is (87500,150000)
# finally, We remove the rows step by step which aren't included.
# and also we'll have 39964 rows!

# %%
auto['date_Crawled'].str[:10].value_counts( normalize=True,dropna=False).head(15)
# Out:
# 2016-04-03    0.038184
# 2016-03-21    0.037534
# 2016-03-12    0.037384
# 2016-03-20    0.037309
# 2016-03-14    0.037158
# 2016-04-04    0.036733
# 2016-03-07    0.036283
# 2016-04-02    0.034706
# 2016-03-28    0.034631
# 2016-03-08    0.034231
# 2016-03-15    0.034006
# 2016-03-30    0.033981
# 2016-03-29    0.033830
# 2016-03-09    0.033805
# 2016-03-19    0.033580
# Name: date_Crawled, dtype: float64

# %%
auto['date_Crawled'].str[:10].describe()
# Out:
# count          39964
# unique            34
# top       2016-04-03
# freq            1526
# Name: date_Crawled, dtype: object

# %%
auto['ad_created'].str[:10].value_counts(normalize=True, dropna=False).head(15)
# Out:
# 2016-04-03    0.038460
# 2016-03-21    0.037659
# 2016-03-20    0.037309
# 2016-04-04    0.037259
# 2016-03-12    0.037234
# 2016-03-14    0.035607
# 2016-03-07    0.035132
# 2016-03-28    0.034606
# 2016-04-02    0.034306
# 2016-03-08    0.034206
# 2016-03-29    0.033931
# 2016-03-15    0.033805
# 2016-03-30    0.033780
# 2016-03-09    0.033680
# 2016-04-01    0.033180
# Name: ad_created, dtype: float64

# %%
auto['ad_created'].str[:10].describe()
# Out:
# count          39964
# unique            68
# top       2016-04-03
# freq            1537
# Name: ad_created, dtype: object

# %%
auto['last_Seen'].str[:10].value_counts( normalize=True,dropna=False).head(15)
# Out:
# 2016-04-06    0.209063
# 2016-04-07    0.122410
# 2016-04-05    0.118457
# 2016-03-17    0.029777
# 2016-04-02    0.025673
# 2016-04-03    0.025623
# 2016-03-12    0.025598
# 2016-03-30    0.025448
# 2016-04-04    0.025323
# 2016-03-31    0.024597
# 2016-04-01    0.024222
# 2016-03-29    0.023046
# 2016-03-22    0.022370
# 2016-03-28    0.022045
# 2016-03-20    0.022020
# Name: last_Seen, dtype: float64

# %%
auto['last_Seen'].str[:10].describe()
# Out:
# count          39964
# unique            34
# top       2016-04-06
# freq            8355
# Name: last_Seen, dtype: object

# %% [markdown]
# ### Explain Observation and Analyze the Results
# after observing the three columns and see their trends, we can understand some features and make some predictions.
# firs of all, for the "data_crawled",
# As we see the dates, as we go forward in the dates,the abundance of them has a ascending rate.
# second, the 'last_seen',
# As we know both columns 'last_seen' & 'data_crawled' are related and there is an algorithm for the ad which posted and the times of showing it. You can see the unique values of thesee columns are same.
# third, the 'ad_created' column,
# it has a swinging rate and the special times like weekend night(saturday night) are the busiest time of the week for example, And if You noticed, it has a ascending rate like the two ones too, Overall!

# %%
auto['registration_year'].describe()
# Out:
# count    39964.000000
# mean      2002.675083
# std         35.644961
# min       1910.000000
# 25%       1999.000000
# 50%       2002.000000
# 75%       2006.000000
# max       9000.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# ### Exploring the 'registration_year'
# as you see, there are some unreal and outliers.The year which eBay has just started is 1995 and these data is for until 2006. So the resume should be removed.

# %%
auto=auto[auto['registration_year'].between(1995,2006)]
auto['registration_year'].value_counts(normalize=True)
# Out:
# 2000    0.111725
# 1999    0.102391
# 2005    0.097329
# 2003    0.091692
# 2001    0.091477
# 2004    0.090938
# 2002    0.085446
# 2006    0.084799
# 1998    0.082968
# 1997    0.069685
# 1996    0.048718
# 1995    0.042830
# Name: registration_year, dtype: float64

# %% [markdown]
# ### Removing the outlier values from 'registration_year'
# as we mentioned the year which ebay is founded and this dataframe includes until 2006, We set the bound between1995-2006
# #### Observing after removing
# As you see, there is a yearly low rate in the first years, But after a while in 1998 and after that, It got a jump and spent some shiny years, but after that is has a steady rate, which could have lot of reasons....

# %%
auto
# Out:
#               date_Crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 11     2016-03-16 18:45:34                         Mercedes_A140_Motorschaden
# 13     2016-03-23 10:48:32                                 Audi_A3_1.6_tuning
# 16     2016-03-16 14:59:02                                Opel_Vectra_B_Kombi
# ...

# %%
auto['brand'].value_counts(normalize=True,dropna=False)
# Out:
# volkswagen        0.206469
# opel              0.126984
# bmw               0.113161
# mercedes_benz     0.094026
# audi              0.078696
# ford              0.076255
# renault           0.058950
# peugeot           0.033532
# fiat              0.025454
# seat              0.018812
# mazda             0.017197
# nissan            0.014899
# citroen           0.012996
# smart             0.012314
# skoda             0.011488
# toyota            0.010519
# volvo             0.010232
# mitsubishi        0.009298
# alfa_romeo        0.007898
# honda             0.007755
# hyundai           0.006426
# kia               0.005637
# sonstige_autos    0.005134
# suzuki            0.004883
# chrysler          0.004667
# mini              0.004380
# daihatsu          0.002872
# chevrolet         0.002441
# subaru            0.002298
# saab              0.002118
# jeep              0.002118
# daewoo            0.002010
# rover             0.001975
# land_rover        0.001651
# ...

# %%
brand_counts = auto["brand"].value_counts(normalize=True)
common_brands = brand_counts[brand_counts > .05].index
print(common_brands)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# German manufacturers represent four out of the top five brands, almost 50% of the overall listings. Volkswagen is by far the most popular brand, with approximately double the cars for sale of the next two brands combined.
#
# There are lots of brands that don't have a significant percentage of listings, so we will limit our analysis to brands representing more than 5% of total listings.

# %%
brand_mean_prices = {}

for brand in common_brands:
    brand_only = auto[auto["brand"] == brand]
    mean_price = brand_only["price"].mean()
    brand_mean_prices[brand] = int(mean_price)

brand_mean_prices

# %% [markdown]
# Of the top 5 brands, there is a distinct price gap:
#
# Audi, BMW and Mercedes Benz are more expensive
# Ford and Opel are less expensive
# Volkswagen is in between - this may explain its popularity, it may be a 'best of 'both worlds' option.

# %%
bmp_series = pd.Series(brand_mean_prices)
pd.DataFrame(bmp_series, columns=["mean_mileage"])

# %%
brand_mean_mileage = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_mileage = brand_only["odometer_km"].mean()
    brand_mean_mileage[brand] = int(mean_mileage)

mean_mileage = pd.Series(brand_mean_mileage).sort_values(ascending=False)
mean_prices = pd.Series(brand_mean_prices).sort_values(ascending=False)

# %%
brand_info = pd.DataFrame(mean_mileage,columns=['mean_mileage'])
brand_info

# %%
brand_info["mean_price"] = mean_prices
brand_info

# %% [markdown]
# The range of car mileages does not vary as much as the prices do by brand, instead all falling within 10% for the top brands. There is a slight trend to the more expensive vehicles having higher mileage, with the less expensive vehicles having lower mileage.
